# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
# %matplotlib inline
import re
import cpi

import plotly.offline
import plotly.graph_objs as go
plotly.offline.init_notebook_mode(connected = True)
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %%
# source of the data https://www.kaggle.com/c/tmdb-box-office-prediction/data

train_df = pd.read_csv('./data/train.csv')
test_df = pd.read_csv('./data/test.csv')

# train_df.head()

# %%
cols = ['original_title', 'title', 'belongs_to_collection', 'genres', 'homepage', 'original_language', 'production_companies', 'runtime', 'release_date', 'budget', 'revenue']
df = train_df[cols]
df.head()
# Out:
#                              original_title  \
# 0                    Hot Tub Time Machine 2
# 1  The Princess Diaries 2: Royal Engagement
# 2                                  Whiplash
# 3                                   Kahaani
# 4                                      마린보이
#
#                                       title  \
# 0                    Hot Tub Time Machine 2
# 1  The Princess Diaries 2: Royal Engagement
# 2                                  Whiplash
# 3                                   Kahaani
# 4                                Marine Boy
#
#                                belongs_to_collection  \
# 0  [{'id': 313576, 'name': 'Hot Tub Time Machine ...
# 1  [{'id': 107674, 'name': 'The Princess Diaries ...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                               genres  \
# 0                     [{'id': 35, 'name': 'Comedy'}]
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                      [{'id': 18, 'name': 'Drama'}]
# 3  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#
#                             homepage original_language  \
# 0                                NaN                en
# 1                                NaN                en
# 2  http://sonyclassics.com/whiplash/                en
# 3         http://kahaanithefilm.com/                hi
# 4                                NaN                ko
#
#                                 production_companies  runtime release_date  \
# 0  [{'name': 'Paramount Pictures', 'id': 4}, {'na...     93.0      2/20/15
# 1        [{'name': 'Walt Disney Pictures', 'id': 2}]    113.0       8/6/04
# 2  [{'name': 'Bold Films', 'id': 2266}, {'name': ...    105.0     10/10/14
# 3                                                NaN    122.0       3/9/12
# 4                                                NaN    118.0       2/5/09
#
#      budget   revenue
# 0  14000000  12314651
# 1  40000000  95149435
# 2   3300000  13092000
# 3   1200000  16000000
# 4         0   3923970

# %%
def col_string_extraction(col_name):

    col_name_list = []

    for i in range(df.shape[0]):
        st = df[col_name].iloc[i]
        # some movies have production compnaies as null
        if type(st) != str:
            col_name_list.append(['NaN'])
        
        else:
            subs = re.findall("\{(.*?)\}", str(st))

            col = []
            for j in range(len(subs)):
                extracted = re.findall("\: '(.*?)\'", subs[j])
                # some entries do not fit in the regex above
                if len(extracted) != 0:
                    col.append(extracted[0])
                else:
                    continue

            col_name_list.append(col)
    
    return col_name_list

# %%
production_company_list = col_string_extraction('production_companies')
genre_list = col_string_extraction('genres')
collection_list = col_string_extraction('belongs_to_collection')
flat_collection_list = [i for sub in collection_list for i in sub]

df.insert(2, 'genre', genre_list)
df.insert(3, 'collection', flat_collection_list)
df.insert(4, 'production_company', production_company_list)

df = df.drop(['genres', 'production_companies', 'belongs_to_collection'], axis = 1)
df.head()
# Out:
#                              original_title  \
# 0                    Hot Tub Time Machine 2
# 1  The Princess Diaries 2: Royal Engagement
# 2                                  Whiplash
# 3                                   Kahaani
# 4                                      마린보이
#
#                                       title                             genre  \
# 0                    Hot Tub Time Machine 2                          [Comedy]
# 1  The Princess Diaries 2: Royal Engagement  [Comedy, Drama, Family, Romance]
# 2                                  Whiplash                           [Drama]
# 3                                   Kahaani                 [Thriller, Drama]
# 4                                Marine Boy                [Action, Thriller]
#
#                         collection  \
# 0  Hot Tub Time Machine Collection
# 1  The Princess Diaries Collection
# 2                              NaN
# 3                              NaN
# 4                              NaN
#
#                                   production_company  \
# 0  [Paramount Pictures, United Artists, Metro-Gol...
# 1                             [Walt Disney Pictures]
# 2  [Bold Films, Blumhouse Productions, Right of W...
# 3                                              [NaN]
# 4                                              [NaN]
#
#                             homepage original_language  runtime release_date  \
# 0                                NaN                en     93.0      2/20/15
# 1                                NaN                en    113.0       8/6/04
# 2  http://sonyclassics.com/whiplash/                en    105.0     10/10/14
# 3         http://kahaanithefilm.com/                hi    122.0       3/9/12
# 4                                NaN                ko    118.0       2/5/09
#
#      budget   revenue
# 0  14000000  12314651
# 1  40000000  95149435
# 2   3300000  13092000
# 3   1200000  16000000
# 4         0   3923970

# %%
# extract release year and store in the following format xxxx

release_year = df['release_date'].apply(lambda x: x.split('/')[-1])

release_year_adj = []

for i in range(len(release_year)):
    if 0 <= int(release_year[i]) <= 20:
        year = str(20) + str(release_year[i])
        release_year_adj.append(year)
    else:
        year = str(19) + str(release_year[i])
        release_year_adj.append(year)
        
df.insert(8, 'release_year', release_year_adj)

# adjustment for revenue 
adjusted_revenue = []
for i in range(df.shape[0]):
    value = cpi.inflate(df['revenue'].iloc[i], int(df['release_year'].iloc[i]), to = 2018)
    adjusted_revenue.append(int(value))
    
df.insert(10, 'adjusted_revenue', adjusted_revenue)

# %% [markdown]
# sequals - revenue, release_date
# language - revenue
# production company - revenue, date

# %% [markdown]
# ### Disney

# %%
# movies produced by walt disney 

disney_movies = []

for i in range(df.shape[0]):
    if 'Walt Disney Pictures' in df['production_company'].iloc[i]:
        name = df['original_title'].iloc[i]
        disney_movies.append(name)

# %%
disney_df = df[df['original_title'].isin(disney_movies)]
disney_df
# Out:
#                                          original_title  \
# 1              The Princess Diaries 2: Royal Engagement
# 8                                Muppet Treasure Island
# 121                                              Tarzan
# 155                                Return to Never Land
# 188                                              WALL·E
# 309                                       Freaky Friday
# 314                                              Cars 3
# 335                                  Million Dollar Arm
# 357                                       The Lion King
# 461                                       The Game Plan
# 585                                                दंगल
# 684                                Beauty and the Beast
# 712                                         Eight Below
# 734                                            Zootopia
# 735                             Honey I Blew Up the Kid
# 791                                  The Little Mermaid
# 804                                   The Jungle Book 2
# 824                                   Home on the Range
# 881                                 Alice in Wonderland
# 922                                       A Goofy Movie
# 941                                          Maleficent
# 974                                                Tron
# 1041                                       The Pacifier
# 1042                                  National Treasure
# 1145              The Santa Clause 3: The Escape Clause
# 1164                               The Three Musketeers
# 1222                                             Cars 2
# 1229                          The Sorcerer's Apprentice
# 1270                                        John Carter
# 1323                          Squanto: A Warrior's Tale
# ...                                                 ...
# 1547                                The Haunted Mansion
# 1554                                           Hercules
# 1624                                           Hercules
# 1856                                       TRON: Legacy
# 1862                                Herbie Fully Loaded
# 1932                      The Odd Life of Timothy Green
# 1962                                         Glory Road
# 1976                                   The Finest Hours
# 2047                                               Prom
# 2097  Pirates of the Caribbean: The Curse of the Bla...
# 2126                     Guardians of the Galaxy Vol. 2
# 2135        Pirates of the Caribbean: On Stranger Tides
# 2209           Pirates of the Caribbean: At World's End
# 2284                                               ゲド戦記
# 2324                               The Three Musketeers
# 2429                                   Tuck Everlasting
# 2442                             Race to Witch Mountain
# 2472                                  The Good Dinosaur
# 2562                                       Finding Dory
# 2629           Homeward Bound II: Lost in San Francisco
# 2669                                         Pocahontas
# 2707                              Max Keeble's Big Move
# 2738                          Atlantis: The Lost Empire
# 2739                                    The Incredibles
# 2771                            Flight of the Navigator
# 2806                                           Sky High
# 2858                                               Cars
# 2866                 National Treasure: Book of Secrets
# 2899                                           Dinosaur
# 2943                          James and the Giant Peach
#
#                                                   title  \
# 1              The Princess Diaries 2: Royal Engagement
# 8                                Muppet Treasure Island
# 121                                              Tarzan
# 155                                Return to Never Land
# 188                                              WALL·E
# 309                                       Freaky Friday
# 314                                              Cars 3
# 335                                  Million Dollar Arm
# 357                                       The Lion King
# 1624  [Animation, Family, Fantasy, Adventure, Comedy...
# 1856               [Adventure, Action, Science Fiction]
# 1862      [Comedy, Family, Adventure, Fantasy, Romance]
# 1932                   [Fantasy, Drama, Comedy, Family]
# 1962                                            [Drama]
# 1976                 [Action, Drama, History, Thriller]
# 2047                                           [Comedy]
# 2097                       [Adventure, Fantasy, Action]
# 2126       [Action, Adventure, Comedy, Science Fiction]
# 2135                       [Adventure, Action, Fantasy]
# 2209                       [Adventure, Fantasy, Action]
# 2284   [Adventure, Fantasy, Animation, Science Fiction]
# 2324                      [Adventure, Action, Thriller]
# 2429  [Drama, Family, Fantasy, Romance, Science Fict...
# 2442  [Adventure, Family, Fantasy, Science Fiction, ...
# 2472                     [Adventure, Animation, Family]
# 2562             [Adventure, Animation, Comedy, Family]
# 2629                 [Adventure, Comedy, Drama, Family]
# 2669              [Adventure, Animation, Drama, Family]
# 2707         [Comedy, Family, Fantasy, Science Fiction]
# 2738    [Animation, Family, Adventure, Science Fiction]
# 2739             [Action, Adventure, Animation, Family]
# 2771               [Family, Science Fiction, Adventure]
# 2806                        [Adventure, Comedy, Family]
# 2858             [Animation, Adventure, Comedy, Family]
# 2866             [Action, Adventure, Mystery, Thriller]
# 2899                                [Animation, Family]
# 2943                     [Adventure, Animation, Family]
#
#                                collection  \
# 1         The Princess Diaries Collection
# 8                   The Muppet Collection
# 121         Tarzan (Animation) Collection
# 155                  Peter Pan Collection
# 188                                   NaN
# 309                                   NaN
# 314                       Cars Collection
# 335                                   NaN
# 357              The Lion King Collection
# 461                                   NaN
# 585                                   NaN
# 684                                   NaN
# 712                                   NaN
# 734                                   NaN
# 735   Honey, I Shrunk the Kids Collection
# 791         The Little Mermaid Collection
# 804            The Jungle Book Collection
# 824                                   NaN
# 881        Alice in Wonderland Collection
# 922              A Goofy Movie Collection
# 941                                   NaN
# 974                       TRON Collection
# 1041                                  NaN
# 1042         National Treasure Collection
# 1145          The Santa Clause Collection
# 1164                                  NaN
# 1222                      Cars Collection
# 1229                                  NaN
# 1270                                  NaN
# 1323                                  NaN
# ...                                   ...
# 1547                                  NaN
# 1554   Hercules (Lou Ferrigno) Collection
# 1624                                  NaN
# 1856                      TRON Collection
# 1862                    Herbie Collection
# 1932                                  NaN
# 1962                                  NaN
# 1976                                  NaN
# 2047                                  NaN
# 2097  Pirates of the Caribbean Collection
# 2126   Guardians of the Galaxy Collection
# 2135  Pirates of the Caribbean Collection
# 2209  Pirates of the Caribbean Collection
# 2284                                  NaN
# 2324                                  NaN
# 2429                                  NaN
# 2442                                  NaN
# 2472                                  NaN
# 2562              Finding Nemo Collection
# 2629            Homeward Bound Collection
# 2669                Pocahontas Collection
# 2707                                  NaN
# 2738                  Atlantis Collection
# 2739           The Incredibles Collection
# 2771                                  NaN
# 2806                                  NaN
# 2858                      Cars Collection
# 2866         National Treasure Collection
# 2899                                  NaN
# 2943                                  NaN
#
#                                      production_company  \
# 1                                [Walt Disney Pictures]
# 8     [Walt Disney Pictures, Jim Henson Productions,...
# 1229   215283742
# 1270   284139100
# 1323     3337685
# ...          ...
# 1547   182290266
# 1554    10676194
# 1624   252712101
# 1856   400062763
# 1862    66002004
# 1932    51854875
# 1962    42647449
# 1976    52099090
# 2047    10130000
# 2097   655011224
# 2126   863416141
# 2135  1045713802
# 2209   961000000
# 2284    68000000
# 2324   132274484
# 2429    19158074
# 2442   106303988
# 2472   331926147
# 2562  1028570889
# 2629    32709423
# 2669   346079773
# 2707    17292381
# 2738   186053725
# 2739   631442092
# 2771    18564613
# 2806    86369815
# 2858   461983149
# 2866   457363168
# 2899   354248063
# 2943    28921264
#
# [64 rows x 13 columns]

# %%
disney_sequel_df = disney_df[disney_df['collection'] != 'NaN']
disney_sequel_df.head()
# Out:
#                                original_title  \
# 1    The Princess Diaries 2: Royal Engagement
# 8                      Muppet Treasure Island
# 121                                    Tarzan
# 155                      Return to Never Land
# 314                                    Cars 3
#
#                                         title  \
# 1    The Princess Diaries 2: Royal Engagement
# 8                      Muppet Treasure Island
# 121                                    Tarzan
# 155                      Return to Never Land
# 314                                    Cars 3
#
#                                           genre  \
# 1              [Comedy, Drama, Family, Romance]
# 8    [Action, Comedy, Music, Family, Adventure]
# 121       [Adventure, Animation, Drama, Family]
# 155     [Adventure, Fantasy, Animation, Family]
# 314      [Family, Comedy, Animation, Adventure]
#
#                           collection  \
# 1    The Princess Diaries Collection
# 8              The Muppet Collection
# 121    Tarzan (Animation) Collection
# 155             Peter Pan Collection
# 314                  Cars Collection
#
#                                     production_company  \
# 1                               [Walt Disney Pictures]
# 8    [Walt Disney Pictures, Jim Henson Productions,...
# 121                             [Walt Disney Pictures]
# 155  [Walt Disney Pictures, Walt Disney Television ...
# 314    [Walt Disney Pictures, Pixar Animation Studios]
#
#                                               homepage original_language  \
# 1                                                  NaN                en
# 8                                                  NaN                en
# 121  http://disneydvd.disney.go.com/tarzanr-special...                en
# 155                                                NaN                en
# 314                             http://cars.disney.com                en
#
#      runtime release_year release_date  adjusted_revenue     budget    revenue
# 1      113.0         2004       8/6/04         126483267   40000000   95149435
# 8      100.0         1996      2/16/96          54938484          0   34327391
# 121     88.0         1999      6/18/99         675245714  150000000  448000000
# 155     72.0         2002      2/14/02         153347907   20000000  109862682
# 314    109.0         2017      6/15/17         358722880  175000000  350170057

# %%
def movie_with_sequels(sequel_df):

    # find movie names with collections 
    collection_names = sequel_df[sequel_df.duplicated(subset = 'collection', keep = 'first')]['collection']
    # movie collection df 
    movie_wcollection = sequel_df[sequel_df['collection'].isin(collection_names)]
    
    # find movie names with collections 
    collection_names = sequel_df[sequel_df.duplicated(subset = 'collection', keep = 'first')]['collection']
    # movie collection df 
    movie_wcollection = sequel_df[sequel_df['collection'].isin(collection_names)]

    # find the total number of movies in the movie collection
    num_movies = movie_wcollection.groupby(['collection']).count().reset_index()[['collection', 'title']].rename(columns = {'title': 'num_movies'})

    # add the finding above to the movie collectin df
    movie_wcollection = pd.merge(num_movies, movie_wcollection, on = 'collection', how = 'left')

    collection_df = movie_wcollection.groupby(['collection', 'original_title']).agg({'release_year': 'sum',
                                                                                    'num_movies': 'sum',
                                                                                    'runtime': 'sum',
                                                                                    'budget': 'sum',
                                                                                    'adjusted_revenue': 'sum'})

    return collection_df

# %%
disney_sequel_df = movie_with_sequels(disney_sequel_df)
# disney_sequel_df

# %%
savanna = ['Dinosaur', 'The Lion King']
castle =  ['Alice in Wonderland', 'Beauty and the Beast']
water =  ['Finding Dory', 'Pirates of the Caribbean: The Curse of the Black Pearl']
jungle = ['Tarzan', 'The Jungle Book 2']

location_list = [savanna, castle, water, jungle]

# %%
location_revenue_df = []

for i in range(len(location_list)):
    location_df = pd.DataFrame({})
    
    for j in range(len(location_list[i])):
        
        movie_name = location_list[i][j] 
        one_df = disney_df[disney_df['original_title'] == movie_name]
        location_df = pd.concat([location_df, one_df])
    
    location_revenue_df.append(location_df)

# %%
data = []

trace = go.Bar(x = ['savanna', 'castle', 'water', 'jungle'],
               y = [location_revenue_df[i]['adjusted_revenue'].sum() for i in range(len(location_revenue_df))])
data.append(trace)
# work on: color of the bars, i.e. blue for water, green for jungle...   

layout = dict(title = 'major sceneries and their revenues',
              xaxis = dict(title = 'major sceneries'),
              yaxis = dict(title = 'revenue (adjusted to the value in 2018)'),
              width = 1000,
              height = 600,
              margin = dict(l = 10, r = 10, b = 200, t = 100, pad = 4))

fig = dict(data = data, layout = layout)

plotly.offline.iplot(fig)
# Out:
# <div id="213ce2b9-46c8-45f2-adfc-e136eb280b2c" style="height: 600px; width: 1000px;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("213ce2b9-46c8-45f2-adfc-e136eb280b2c", [{"type": "bar", "x": ["savanna", "castle", "water", "jungle"], "y": [1852155212, 2474658030, 1970042554, 860409832]}], {"title": "major sceneries and their revenues", "xaxis": {"title": "major sceneries"}, "yaxis": {"title": "revenue (adjusted to the value in 2018)"}, "width": 1000, "height": 600, "margin": {"l": 10, "r": 10, "b": 200, "t": 100, "pad": 4}}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>

# %% [markdown]
# ### Sequels

# %%
sequel_df = df[df['collection'] != 'NaN']
sequel_df.head()
# Out:
#                                 original_title  \
# 0                       Hot Tub Time Machine 2
# 1     The Princess Diaries 2: Royal Engagement
# 8                       Muppet Treasure Island
# 10                                       Rocky
# 11  Revenge of the Nerds II: Nerds in Paradise
#
#                                          title  \
# 0                       Hot Tub Time Machine 2
# 1     The Princess Diaries 2: Royal Engagement
# 8                       Muppet Treasure Island
# 10                                       Rocky
# 11  Revenge of the Nerds II: Nerds in Paradise
#
#                                          genre  \
# 0                                     [Comedy]
# 1             [Comedy, Drama, Family, Romance]
# 8   [Action, Comedy, Music, Family, Adventure]
# 10                                     [Drama]
# 11                                    [Comedy]
#
#                          collection  \
# 0   Hot Tub Time Machine Collection
# 1   The Princess Diaries Collection
# 8             The Muppet Collection
# 10                 Rocky Collection
# 11  Revenge of the Nerds Collection
#
#                                    production_company homepage  \
# 0   [Paramount Pictures, United Artists, Metro-Gol...      NaN
# 1                              [Walt Disney Pictures]      NaN
# 8   [Walt Disney Pictures, Jim Henson Productions,...      NaN
# 10                                   [United Artists]      NaN
# 11  [Twentieth Century Fox Film Corporation, Amerc...      NaN
#
#    original_language  runtime release_year release_date  adjusted_revenue  \
# 0                 en     93.0         2015      2/20/15          13046722
# 1                 en    113.0         2004       8/6/04         126483267
# 8                 en    100.0         1996      2/16/96          54938484
# 10                en    119.0         1976     11/21/76         517373744
# 11                en     98.0         1987      7/10/87          50049057
#
#       budget    revenue
# 0   14000000   12314651
# 1   40000000   95149435
# 8          0   34327391
# 10   1000000  117235147
# 11         0   22642033

# %%
collection_df = movie_with_sequels(sequel_df)
# collection_df

# %%
collection_to_plot = ['Alien Collection', 'Resident Evil Collection', 'Transformers Collection', 'The Fast and the Furious Collection', 'Ice Age Collection']

list_of_df = []

for i in range(len(collection_to_plot)):
    
    one_collection_df = collection_df[collection_df['num_movies'] == 4].loc[collection_to_plot[i]].reset_index()
    one_collection_df = one_collection_df.sort_values('release_year')
    
    list_of_df.append(one_collection_df)

# %%
data = []

for i in range(len(list_of_df)):
    trace = go.Scatter( x = list_of_df[i]['original_title'],
                        y = list_of_df[i]['adjusted_revenue'],
                        name = collection_to_plot[i],                   
                        mode = 'lines+markers')
    data.append(trace)
    

layout = dict(title = 'movie sequels and their revenues',
              xaxis = dict(title = 'movie name'),
              yaxis = dict(title = 'revenue (adjusted to the value in 2018)'),
              width = 1000,
              height = 600,
              margin = dict(l = 50, r = 10, b = 200, t = 100, pad = 4))

fig = dict(data = data, layout = layout)

plotly.offline.iplot(fig)
plotly.offline.plot(fig, filename = 'movie_sequels_and_revenues')
# Out:
# <div id="918348f0-73eb-4332-af3d-1d09163916d2" style="height: 600px; width: 1000px;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("918348f0-73eb-4332-af3d-1d09163916d2", [{"type": "scatter", "x": ["Alien", "Aliens", "Alien\u00b3", "Alien: Resurrection"], "y": [362935396, 420000411, 285960481, 253453794], "name": "Alien Collection", "mode": "lines+markers"}, {"type": "scatter", "x": ["Resident Evil", "Resident Evil: Afterlife", "Resident Evil: Retribution", "Resident Evil: The Final Chapter"], "y": [143747747, 345734001, 262662221, 326683426], "name": "Resident Evil Collection", "mode": "lines+markers"}, {"type": "scatter", "x": ["Transformers", "Transformers: Revenge of the Fallen", "Transformers: Dark of the Moon", "Transformers: The Last Knight"], "y": [859512755, 978852543, 1254476711, 619717716], "name": "Transformers Collection", "mode": "lines+markers"}, {"type": "scatter", "x": ["The Fast and the Furious", "The Fast and the Furious: Tokyo Drift", "Fast & Furious", "Furious 7"], "y": [293904260, 197383419, 425069284, 1595791686], "name": "The Fast and the Furious Collection", "mode": "lines+markers"}, {"type": "scatter", "x": ["Ice Age", "Ice Age: The Meltdown", "Ice Age: Dawn of the Dinosaurs", "Ice Age: Collision Course"], "y": [534955806, 823248295, 1037831546, 427475267], "name": "Ice Age Collection", "mode": "lines+markers"}], {"title": "movie sequels and their revenues", "xaxis": {"title": "movie name"}, "yaxis": {"title": "revenue (adjusted to the value in 2018)"}, "width": 1000, "height": 600, "margin": {"l": 50, "r": 10, "b": 200, "t": 100, "pad": 4}}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>
# /Users/yueying.teng/miniconda3/lib/python3.6/site-packages/plotly/offline/offline.py:459: UserWarning:
#
# Your filename `movie_sequels_and_revenues` didn't end with .html. Adding .html to the end of your file.
# 'file:///Users/yueying.teng/Documents/TMDB/movie_sequels_and_revenues.html'
